# %%
age = 20
if age >= 18:
    print("Adult")
# Out:
# Adult

# %%
var = True
print(type(var))
# Out:
# <class 'bool'>

# %%
age = 16
if age >= 18:
  print("eligible")
else:
  print("not eligible")
# Out:
# not eligible

# %%
fare = 50
if fare>50:
  print("high fare")
else:
  print("low fare")
# Out:
# low fare

# %%
# if-elif-else
marks = 72
if marks >= 90:
  print("A+")
elif marks >= 75:
  print("A")
elif marks >= 60:
  print("B")
elif marks >=50:
  print("C")
else:
  print("fail")
# Out:
# B

# %%
age = 25
fare =80
if age >=18 and fare >=50:
  print("condition satisfied")
# Out:
# condition satisfied

# %%
age = 25
survived = 1
if age >=18:
  if survived == 1:
    print("adult survivor")
# Out:
# adult survivor

# %%
# list
# ordered, indexed, mutable, can contain duplicate values, list use square brackets []


my_list = []
my_list
# Out:
# []

# %%
ages = [22,38,36,35,45,46]
names = ["riya","priya","kriya","shreya"]
mixed = [10,"python",3.5,True]
print(ages)
print(names)
print(mixed)
# Out:
# [22, 38, 36, 35, 45, 46]
# ['riya', 'priya', 'kriya', 'shreya']
# [10, 'python', 3.5, True]

# %% [markdown]
# Indexing and slicing

# %%
print(ages[0])
print(names[0])
print(names[-1])
print(names[-2])
print(ages[1:4])
# Out:
# 22
# riya
# shreya
# kriya
# [38, 36, 35]

# %%
print(ages[::2]) # print even indexes
# Out:
# [22, 36, 45]

# %%
print(ages[::-1])
# Out:
# [46, 45, 35, 36, 38, 22]

# %%
ages = [22,23,24,25,27]
ages[4] = 26
print(ages)
# Out:
# [22, 23, 24, 25, 26]

# %%
names.append("siya")
print(names)
# Out:
# ['riya', 'priya', 'kriya', 'shreya', 'siya']

# %%
names.insert(1,"daya")
print(names)
# Out:
# ['riya', 'daya', 'priya', 'kriya', 'shreya', 'siya']

# %%
names.extend(["neha" , "rishab"])
print(names)
# Out:
# ['riya', 'daya', 'priya', 'kriya', 'shreya', 'siya', 'neha', 'rishab']

# %%
names.remove("rishab")
print(names)
# Out:
# ['riya', 'daya', 'priya', 'kriya', 'shreya', 'siya', 'neha']

# %%
removed = names.pop(-1)
print(removed)
# Out:
# neha

# %%
numbers = [10,20,30,40,50,60]
del numbers[1]
print(numbers)
del numbers[-1]
print(numbers)
# Out:
# [10, 30, 40, 50, 60]
# [10, 30, 40, 50]

# %%
numbers.clear()
print(numbers)
# Out:
# []

# %%
numbers = [2,6,8,6,0,7]
print(len(numbers))
# Out:
# 6

# %%
print(numbers.count(2))
# Out:
# 1

# %%
print(numbers.index(6))
# Out:
# 1

# %%
print(6 in numbers)
# Out:
# True

# %%
print(max(numbers))
print(min(numbers))
# Out:
# 8
# 0

# %%
numbers.reverse()
print(numbers)
# Out:
# [7, 0, 6, 8, 6, 2]

# %%
numbers.sort()
print(numbers)
# Out:
# [0, 2, 6, 6, 7, 8]

# %%
print(sum(numbers))
# Out:
# 29

# %%
numbers.reverse()
print(numbers)
# Out:
# [8, 7, 6, 6, 2, 0]

# %%
# nested list
students = [
    ["sam",1,"cse"],
    ["riya",2,"EEE"],
    ["priya",3,"EEE"]
]
print(students[0])
print(students[1][0])
print(students[2][2])
# Out:
# ['sam', 1, 'cse']
# riya
# EEE

# %%
students.append(("neeraj",21,"IT"))
print(students)
# Out:
# [['sam', 1, 'cse'], ['riya', 2, 'EEE'], ['priya', 3, 'EEE'], ('neeraj', 21, 'IT')]

# %%
for student in students:
  for value in student:
    print(value)
# Out:
# sam
# 1
# cse
# riya
# 2
# EEE
# priya
# 3
# EEE
# neeraj
# 21
# IT

# %%
marks = [40,45,90,20,25,60]
for mark in marks:
  if mark >=50:
    print(mark,"pass")
  else:
    print(mark,"fail")
# Out:
# 40 fail
# 45 fail
# 90 pass
# 20 fail
# 25 fail
# 60 pass

# %% [markdown]
# MAK A DATA FRAME

# %%
import pandas as pd

# %%
data = {
    "cust_ID" : [101,102,103,104,105],
    "name" : ["riya","priya","siya", "xyz","qwe"],
    "Age" : [20,30,40,50,60],
    "amount" : [120, 130,480,90, 50]
}
print(data)
# Out:
# {'cust_ID': [101, 102, 103, 104, 105], 'name': ['riya', 'priya', 'siya', 'xyz', 'qwe'], 'Age': [20, 30, 40, 50, 60], 'amount': [120, 130, 480, 90, 50]}

# %%
import pandas as pd

df = pd.DataFrame(data)
print(df)
# Out:
#    cust_ID   name  Age  amount
# 0      101   riya   20     120
# 1      102  priya   30     130
# 2      103   siya   40     480
# 3      104    xyz   50      90
# 4      105    qwe   60      50

# %%
df.iloc[0]
# Out:
# cust_ID     101
# name       riya
# Age          20
# amount      120
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#    cust_ID   name  Age  amount
# 0      101   riya   20     120
# 1      102  priya   30     130
# 2      103   siya   40     480

# %%
df.iloc[0:5 , 0:3]
# Out:
#    cust_ID   name  Age
# 0      101   riya   20
# 1      102  priya   30
# 2      103   siya   40
# 3      104    xyz   50
# 4      105    qwe   60

# %%
df.loc[0:3,["cust_ID","name"]]
# Out:
#    cust_ID   name
# 0      101   riya
# 1      102  priya
# 2      103   siya
# 3      104    xyz

# %%
df.loc[df["age"]>20, [cust_ID]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_544/3029125397.py in <cell line: 0>()
# ----> 1 df.loc[df["age"]>20, [cust_ID]]
#
# ...
